# %% [markdown]
# ## Lab1
#
# By Ali Maamoun

# %%
import pandas as pd

df = pd.read_csv('data.csv', index_col = 0)
df
# Out:
#            ID                Name  Age  \
# 0      158023            L. Messi   31
# 1       20801   Cristiano Ronaldo   33
# 2      190871           Neymar Jr   26
# 3      193080              De Gea   27
# 4      192985        K. De Bruyne   27
# ...       ...                 ...  ...
# 18202  238813        J. Lundstram   19
# 18203  243165  N. Christoffersson   19
# 18204  241638           B. Worman   16
# 18205  246268      D. Walker-Rice   17
# 18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4      https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# ...                                               ...         ...
# ...

# %%
table = df.describe()
table
#table shows all data, we just want Age info for Max and Average
# Out:
#                   ID           Age       Overall     Potential       Special  \
# count   18207.000000  18207.000000  18207.000000  18207.000000  18207.000000
# mean   214298.338606     25.122206     66.238699     71.307299   1597.809908
# std     29965.244204      4.669943      6.908930      6.136496    272.586016
# min        16.000000     16.000000     46.000000     48.000000    731.000000
# 25%    200315.500000     21.000000     62.000000     67.000000   1457.000000
# 50%    221759.000000     25.000000     66.000000     71.000000   1635.000000
# 75%    236529.500000     28.000000     71.000000     75.000000   1787.000000
# max    246620.000000     45.000000     94.000000     95.000000   2346.000000
#
#        International Reputation     Weak Foot   Skill Moves  Jersey Number  \
# count              18159.000000  18159.000000  18159.000000   18147.000000
# mean                   1.113222      2.947299      2.361308      19.546096
# ...

# %%
info = df.info()
#info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18207 entries, 0 to 18206
# Data columns (total 88 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        18207 non-null  int64
#  1   Name                      18207 non-null  object
#  2   Age                       18207 non-null  int64
#  3   Photo                     18207 non-null  object
#  4   Nationality               18207 non-null  object
#  5   Flag                      18207 non-null  object
#  6   Overall                   18207 non-null  int64
#  7   Potential                 18207 non-null  int64
#  8   Club                      17966 non-null  object
#  9   Club Logo                 18207 non-null  object
#  10  Value                     18207 non-null  object
#  11  Wage                      18207 non-null  object
#  12  Special                   18207 non-null  int64
# ...

# %% [markdown]
# #### Find Average Age

# %%
age_table = table['Age']
type(ave_age)
ave_age = int(age_table['mean'])
ave_age
# Out:
# 25

# %% [markdown]
# #### Find Max Age

# %%
max_age = ave_age['max']
max_age
name_max_age = table

# %% [markdown]
# found `max_age`, now need to find their name

# %%
import numpy as np
age_list = df['Age']
# age_list = np.array(age_list)
age_list
#to find the eldest, we want the index of who has the max age as found in ave_age table
max_age_index = age_list.iloc[int(max_age)]
max_age_index
# Out:
# 25

# %% [markdown]
# Now we have `max_age_index`

# %%
df['Age'] == max_age
max_age_player = df[df['Age'] == max_age]
max_age_player
max_age_player_name = max_age_player.Name
max_age_player_name
# Out:
# 4741    O. Pérez
# Name: Name, dtype: object

# %% [markdown]
# #### Find Highest Salary

# %%
salary = df['Release Clause']
salary
for x in range(salary.size):
    salary[x] = int(float(salary[x].strip('€ M')))
salary
# Out:
# <ipython-input-278-b7ed7f26efba>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   salary[x] = int(float(salary[x].strip('€ M')))
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-278-b7ed7f26efba> in <module>
#       2 salary
#       3 for x in range(salary.size):
# ----> 4     salary[x] = int(float(salary[x].strip('€ M')))
#       5 salary
#
# AttributeError: 'float' object has no attribute 'strip'

# %% [markdown]
# I know its Messi with the highest salary but my python knowledge is lacking me

# %% [markdown]
# #### Create Histogram of Players' Age

# %%
import matplotlib.pyplot as plt
#%matplotlib inLine

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
player_ids = df.index
ax.bar(player_ids,age_list)

ax.set_title('FIFA Player Age')
ax.set_xlabel('Player ID')
ax.set_ylabel('Age')

plt.show()

# %% [markdown]
# #### Correlation matrix

# %%
import seaborn as sns

corr = df.corr()


age_corr = corr['Age']
crossing_corr = corr['Crossing']
penalties_corr = corr['Penalties']
strength_corr = corr['Strength']
weakFoot_corr= corr['Weak Foot']
stamina_corr = corr['Stamina']
skill_corr = corr['Skill Moves']
finishing_corr = corr['Finishing']

corr = pd.DataFrame([age_corr, crossing_corr, penalties_corr, strength_corr, weakFoot_corr, stamina_corr])

corr

plt.figure(figsize=(40,10))
sns.heatmap(corr, annot=True, annot_kws={'size':13}, cmap="RdYlGn")
# Out:
# <AxesSubplot:>

# %% [markdown]
# Couldnt figure out how to change the x axis, but these correlations are kind of interesting to see how age affects some of the more demanding physical movement, but I honestly don't see that big of a correlation unless I'm reading this wrong
#
# The ones I chose on the y axis would be very interesting to see in a better picture, I just don't know how to do that with sns...

# %% [markdown]
# #### More Visualizations

# %%
plt.plot(age_corr, color='red')
plt.plot(strength_corr, color='blue')

plt.show()

# %%
plt.xlabel('Skill')
plt.ylabel('Finishing')
plt.legend
plt.scatter(skill_corr,finishing_corr)

# %% [markdown]
# Wanted to see correlation between those with high skill and finishing the goal... seems like there are alot with high skill and finishing as well like expected with a few averaging out with little correlation
